# %% [markdown]
# # Introduction to Apache Spark Resilient Distributed Datasets (RDD)

# %% [markdown]
# ### Initialization ###
# Starting Spark session:

# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder.getOrCreate()
# Out:
# 24/10/08 09:10:28 WARN Utils: Your hostname, MacBook-Pro-BartomiejK.local resolves to a loopback address: 127.0.0.1; using 10.129.4.207 instead (on interface en0)
# 24/10/08 09:10:28 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 24/10/08 09:10:29 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://10.129.4.207:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.5.3</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>pyspark-shell</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
sc = spark.sparkContext

# %% [markdown]
# ### Reading text files

# %% [markdown]
# Download a file locally (just for the demo, for larger files use HDFS or S3):

# %%
import urllib.request

# %%
urllib.request.urlretrieve("http://raw.githubusercontent.com/elastic/examples/master/Common%20Data%20Formats/apache_logs/apache_logs","apache_logs")
# Out:
# ('apache_logs', <http.client.HTTPMessage at 0x106be9150>)

# %% [markdown]
# Create a first RDD

# %%
lines = sc.textFile("apache_logs")

# %% [markdown]
# Perform a *transformation*

# %%
lineLengths = lines.map(lambda s: len(s))

# %% [markdown]
# Perform an *action*

# %%
totalLength = lineLengths.reduce(lambda a, b: a + b)

# %% [markdown]
# Finally evaluate (laziness!)

# %%
totalLength
# Out:
# 2360789

# %% [markdown]
# ### Custom functions

# %%
def myFunc(s):
    words = s.split(" ")
    return len(words)

# %%
wordCounts = lines.map(myFunc)

# %%
wordCounts.max()
# Out:
# 43

# %%
wordCounts.histogram([0,10,20,30,40,50])
# Out:
# ([0, 10, 20, 30, 40, 50], [0, 4901, 4719, 378, 2])

# %%
wordCounts.count()
# Out:
# 10000

# %% [markdown]
# ### Map-Reduce pattern

# %% [markdown]
# Let's look closer at our log file format:
#
# ```
# 99.158.0.150 - - [18/May/2015:04:05:37 +0000] "GET /images/jordan-80.png HTTP/1.1" 200 6146 "http://www.semicomplete.com/articles/dynamic-dns-with-dhcp/" "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/32.0.1700.102 Chrome/32.0.1700.102 Safari/537.36"
# ```
#
# Count lines containing "Chrome":

# %%
chromeLines = lines.map(lambda s: (1 if "Chrome" in s else 0)).repartition(5)

# %%
counts = chromeLines.reduce(lambda a, b: a + b)

# %%
counts
# Out:
# 3172

# %%
#chromeLines.num

# %% [markdown]
# ### Key-Value Pairs
#
# Count IP addresses

# %%
regex = '([(\d\.)]+)'

# %%
import re

# %%
ip = re.match(regex, '99.158.0.150 - - ').group(0)

# %%
print(ip)
# Out:
# 99.158.0.150

# %%
ips = lines.map(lambda s: (re.match(regex, s).group(0) ,1))

# %%
ipCounts = ips.reduceByKey(lambda a, b: a + b)

# %% [markdown]
# Get results

# %%
ipCounts.collect()
# Out:
# [('83.149.9.216', 23),
#  ('110.136.166.128', 6),
#  ('46.105.14.53', 364),
#  ('123.125.71.35', 1),
#  ('200.49.190.100', 1),
#  ('67.214.178.190', 2),
#  ('207.241.237.220', 18),
#  ('207.241.237.227', 17),
#  ('207.241.237.228', 16),
#  ('218.30.103.62', 16),
#  ('71.212.224.97', 5),
#  ('86.1.76.62', 6),
#  ('107.170.41.69', 10),
#  ('208.115.111.72', 83),
#  ('174.37.205.76', 1),
#  ('134.76.249.10', 8),
#  ('123.125.71.117', 1),
#  ('65.19.138.34', 3),
#  ('5.102.173.71', 2),
#  ('187.45.193.158', 8),
#  ('36.38.8.174', 6),
#  ('71.207.12.53', 2),
#  ('220.241.45.142', 2),
#  ('146.1.1.2', 15),
#  ('178.255.215.83', 22),
#  ('50.131.51.216', 17),
#  ('212.197.170.45', 2),
#  ('108.32.74.68', 14),
#  ('180.76.5.27', 1),
#  ('93.164.60.142', 1),
#  ('108.178.4.100', 2),
#  ('111.199.235.239', 37),
#  ('108.171.116.194', 65),
#  ('94.175.135.116', 1),
#  ('207.241.237.104', 13),
#  ('83.31.73.148', 2),
#  ('180.76.6.156', 2),
#  ('92.108.120.46', 2),
#  ('172.56.29.98', 1),
#  ('173.252.73.114', 1),
#  ('217.69.133.70', 4),
#  ('217.69.133.237', 4),
#  ('209.17.114.78', 40),
#  ('202.156.10.11', 2),
#  ('65.55.213.73', 60),
#  ('84.85.130.133', 12),
#  ('54.226.176.99', 1),
#  ('194.29.137.5', 14),
#  ('95.153.89.104', 1),
#  ('173.192.238.58', 3),
#  ('74.125.176.149', 6),
#  ('50.18.71.222', 1),
#  ('107.170.40.203', 4),
#  ('207.241.237.221', 9),
#  ('37.130.227.133', 1),
#  ('109.167.131.110', 7),
#  ('74.125.176.151', 8),
#  ('88.184.51.134', 7),
#  ('143.233.204.28', 9),
#  ('67.61.162.49', 6),
#  ('222.77.201.107', 4),
#  ('176.31.103.52', 12),
#  ('180.76.5.149', 1),
#  ('144.76.95.39', 27),
#  ('198.143.156.2', 2),
#  ('120.202.255.147', 10),
#  ('108.91.82.251', 7),
#  ('46.119.119.29', 3),
#  ('207.241.237.224', 12),
#  ('197.206.232.180', 1),
#  ('180.76.6.53', 2),
#  ('166.82.99.140', 1),
#  ('216.14.102.16', 9),
#  ('107.170.40.205', 4),
#  ('219.137.88.123', 1),
#  ('74.125.176.148', 6),
#  ('46.165.197.151', 2),
#  ('91.221.131.30', 19),
#  ('157.56.92.164', 1),
#  ('180.76.5.59', 1),
#  ('199.16.156.124', 7),
#  ('120.59.2.54', 6),
#  ('98.216.194.189', 4),
#  ('64.237.35.242', 4),
#  ('180.76.6.57', 1),
#  ('71.9.98.194', 6),
#  ('187.214.29.27', 1),
#  ('217.71.46.55', 1),
#  ('128.237.28.16', 1),
#  ('122.166.142.108', 34),
#  ('195.250.34.144', 3),
#  ('131.191.91.87', 1),
#  ('67.170.98.63', 9),
#  ('207.255.245.133', 6),
#  ('37.31.40.234', 2),
#  ('54.219.117.220', 1),
#  ('188.122.8.79', 13),
#  ('217.69.133.238', 5),
#  ('180.76.5.22', 3),
#  ('123.125.71.116', 1),
#  ('68.193.198.76', 1),
#  ('220.181.108.149', 1),
#  ('112.110.247.244', 2),
#  ('112.110.247.250', 1),
#  ('112.110.247.236', 1),
#  ('46.32.254.207', 1),
#  ('190.73.45.219', 2),
#  ('195.211.162.22', 2),
#  ('178.216.54.152', 2),
#  ('108.77.164.97', 1),
#  ('84.137.208.44', 9),
#  ('85.11.191.105', 1),
#  ('93.152.153.38', 5),
#  ('54.226.35.19', 1),
#  ('64.128.17.78', 1),
#  ('157.55.33.114', 1),
#  ('65.172.240.122', 6),
#  ('213.10.136.118', 7),
#  ('203.81.69.86', 1),
#  ('76.2.185.161', 7),
#  ('189.170.95.135', 7),
#  ('24.147.91.100', 6),
#  ('180.76.6.231', 1),
#  ('216.152.249.242', 25),
#  ('74.125.19.80', 5),
#  ('23.105.131.247', 1),
#  ('95.49.190.247', 2),
#  ('54.219.60.151', 1),
#  ('98.206.132.188', 3),
#  ('61.119.116.21', 1),
#  ('218.240.60.244', 2),
#  ('216.151.154.100', 2),
#  ('157.55.32.185', 1),
#  ('82.145.208.98', 6),
#  ('123.125.71.97', 2),
#  ('37.72.189.120', 2),
#  ('88.80.20.186', 2),
#  ('24.183.21.30', 1),
#  ('180.180.100.65', 2),
#  ('117.28.234.67', 7),
#  ('201.26.152.202', 18),
#  ('216.152.243.146', 2),
#  ('91.236.75.26', 1),
#  ('157.56.92.141', 1),
#  ('189.214.42.128', 6),
#  ('119.36.179.179', 7),
#  ('211.150.124.10', 1),
#  ('118.169.39.21', 7),
#  ('116.212.243.74', 1),
#  ('50.2.225.180', 2),
#  ('54.246.137.243', 2),
#  ('66.49.182.146', 1),
#  ('112.216.234.90', 3),
#  ('89.68.134.81', 8),
#  ('2.51.241.128', 2),
#  ('96.242.86.110', 2),
#  ('123.125.71.85', 1),
#  ('201.141.65.112', 1),
#  ('157.55.32.84', 1),
#  ('190.239.74.15', 1),
#  ('157.55.35.80', 1),
#  ('5.39.15.151', 2),
#  ('208.50.255.30', 2),
#  ('122.248.149.254', 2),
#  ('14.203.126.78', 3),
#  ('128.61.85.15', 7),
#  ('122.167.215.241', 4),
#  ('66.249.80.128', 2),
#  ('106.187.98.170', 1),
#  ('125.236.205.70', 1),
#  ('74.125.19.215', 1),
#  ('217.116.157.26', 7),
#  ('189.148.62.33', 1),
#  ('117.192.147.163', 1),
#  ('14.1.42.114', 1),
#  ('180.76.5.193', 2),
#  ('188.250.157.192', 6),
#  ('203.219.2.2', 6),
#  ('125.239.81.249', 1),
#  ('80.133.249.216', 6),
#  ('50.8.159.176', 7),
#  ('203.211.107.162', 1),
#  ('204.19.246.36', 1),
#  ('180.76.5.118', 2),
#  ('122.60.77.197', 2),
#  ('42.156.136.43', 1),
#  ('208.71.68.122', 1),
#  ('65.55.215.237', 3),
#  ('107.170.40.201', 4),
#  ('92.230.101.44', 2),
#  ('180.76.6.66', 1),
#  ('5.39.4.211', 1),
#  ('67.215.172.14', 1),
#  ('69.167.81.126', 2),
#  ('76.164.234.106', 2),
#  ('176.181.182.132', 2),
#  ('122.61.197.176', 1),
#  ('65.55.215.37', 4),
#  ('180.76.5.145', 1),
#  ('207.158.15.119', 1),
#  ('216.14.198.50', 8),
#  ('27.252.40.146', 1),
#  ('180.76.6.130', 2),
#  ('122.57.207.174', 1),
#  ('174.51.6.146', 6),
#  ('180.76.5.147', 1),
#  ('203.173.194.136', 1),
#  ('211.25.11.99', 3),
#  ('210.19.254.116', 1),
#  ('116.50.181.5', 6),
#  ('46.161.41.24', 3),
#  ('180.76.5.26', 1),
#  ('194.254.139.66', 2),
#  ('115.77.7.145', 7),
#  ('82.80.23.217', 1),
#  ('213.252.7.178', 6),
#  ('183.91.14.219', 1),
#  ('180.76.5.119', 1),
#  ('207.45.249.135', 5),
#  ('218.28.225.87', 1),
#  ('128.141.154.221', 1),
#  ('220.181.51.37', 1),
#  ('62.44.32.116', 6),
#  ('98.130.2.118', 1),
#  ('49.50.247.181', 1),
#  ('192.3.183.199', 2),
#  ('103.9.43.132', 1),
#  ('92.163.85.51', 6),
#  ('180.76.6.153', 1),
#  ('195.27.15.134', 1),
#  ('113.212.70.121', 3),
#  ('184.154.153.210', 2),
#  ('180.76.6.148', 1),
#  ('203.122.224.39', 6),
#  ('193.252.149.222', 6),
#  ('61.135.169.84', 6),
#  ('193.58.82.178', 3),
#  ('197.187.26.144', 1),
#  ('74.93.1.97', 1),
#  ('113.212.68.167', 2),
#  ('66.249.93.91', 2),
#  ('85.248.108.8', 6),
#  ('118.186.69.62', 2),
#  ('173.252.74.113', 1),
#  ('173.252.74.112', 1),
#  ('173.252.77.116', 1),
#  ('122.57.173.238', 1),
#  ('162.210.196.130', 2),
#  ('66.249.80.24', 1),
#  ('46.29.8.202', 2),
#  ('180.76.5.116', 1),
#  ('204.93.54.238', 2),
#  ('81.52.143.26', 1),
#  ('78.134.38.242', 1),
#  ('129.121.176.228', 1),
#  ('204.244.74.22', 2),
#  ('193.225.194.254', 6),
#  ('155.140.133.248', 8),
#  ('89.218.93.74', 12),
#  ('75.132.156.143', 6),
#  ('82.200.166.110', 1),
#  ('216.109.99.4', 7),
#  ('176.10.104.96', 2),
#  ('67.220.144.166', 2),
#  ('63.249.66.212', 2),
#  ('178.172.239.240', 5),
#  ('88.234.222.56', 1),
#  ('180.76.5.213', 1),
#  ('5.9.143.150', 1),
#  ('202.65.36.249', 1),
#  ('37.115.190.128', 1),
#  ('172.245.214.208', 2),
#  ('60.53.124.75', 1),
#  ('195.228.139.91', 7),
#  ('80.254.147.68', 1),
#  ('160.92.7.69', 6),
#  ('78.173.140.106', 3),
#  ('183.63.83.14', 1),
#  ('93.210.154.199', 6),
#  ('115.114.17.146', 6),
#  ('61.16.241.98', 6),
#  ('70.210.13.207', 2),
#  ('54.215.29.126', 1),
#  ('188.80.229.128', 6),
#  ('14.141.56.98', 15),
#  ('24.21.55.63', 6),
#  ('24.111.34.227', 1),
#  ('185.5.152.85', 1),
#  ('188.240.136.240', 2),
#  ('173.242.120.61', 3),
#  ('173.213.76.77', 2),
#  ('89.191.52.88', 7),
#  ('186.93.30.106', 1),
#  ('182.68.184.78', 2),
#  ('195.14.103.53', 7),
#  ('46.118.116.232', 1),
#  ('193.244.33.47', 35),
#  ('125.237.203.218', 1),
#  ('183.87.253.120', 6),
#  ('80.239.169.204', 6),
#  ('36.250.177.94', 1),
#  ('217.91.18.234', 6),
#  ('95.78.54.93', 3),
#  ('5.56.158.218', 6),
#  ('85.76.162.29', 1),
#  ('122.107.211.222', 2),
#  ('63.223.125.175', 2),
#  ('93.191.160.193', 6),
#  ('88.8.30.135', 3),
#  ('178.140.172.164', 1),
#  ('147.142.186.54', 6),
#  ('213.160.130.242', 1),
#  ('220.181.127.18', 1),
#  ('213.17.226.11', 6),
#  ('198.245.61.43', 3),
#  ('204.236.153.140', 1),
#  ('121.209.208.128', 6),
#  ('217.12.185.5', 25),
#  ('103.25.13.22', 1),
#  ('61.135.190.100', 1),
#  ('180.180.78.19', 2),
#  ('199.119.124.45', 1),
#  ('218.30.103.114', 2),
#  ('129.70.212.93', 7),
#  ('178.203.37.192', 10),
#  ('37.79.145.225', 1),
#  ('193.104.184.225', 7),
#  ('183.60.244.24', 1),
#  ('110.159.23.90', 8),
#  ('87.216.109.88', 6),
#  ('101.119.18.35', 33),
#  ('31.35.64.245', 6),
#  ('67.220.144.83', 2),
#  ('117.195.177.223', 6),
#  ('198.20.79.140', 2),
#  ('182.64.207.187', 2),
#  ('188.65.166.78', 1),
#  ('54.227.17.146', 1),
#  ('54.204.217.52', 1),
#  ('194.126.102.178', 12),
#  ('130.88.99.231', 1),
#  ('217.174.111.254', 5),
#  ('46.65.248.177', 6),
#  ('88.61.50.114', 1),
#  ('109.195.177.171', 6),
#  ('77.241.193.88', 10),
#  ('213.87.123.186', 1),
#  ('89.212.62.88', 6),
#  ('173.176.91.196', 1),
#  ('118.92.157.140', 1),
#  ('199.247.189.63', 6),
#  ('20.137.2.50', 1),
#  ('176.198.189.108', 1),
#  ('180.76.6.49', 1),
#  ('213.133.224.50', 1),
#  ('212.51.173.12', 27),
#  ('88.152.28.187', 1),
#  ('95.87.197.134', 6),
#  ('41.248.194.136', 1),
#  ('162.44.252.21', 6),
#  ('139.184.30.132', 9),
#  ('83.139.110.254', 1),
#  ('194.186.207.105', 33),
#  ('123.125.71.56', 1),
#  ('69.167.130.5', 9),
#  ('193.24.88.211', 7),
#  ('180.76.6.50', 1),
#  ('213.124.13.242', 2),
#  ('105.224.234.235', 1),
#  ('113.189.161.125', 1),
#  ('85.89.160.218', 7),
#  ('67.220.144.226', 2),
#  ('78.166.243.242', 1),
#  ('194.45.150.17', 6),
#  ('39.41.133.216', 1),
#  ('124.124.1.57', 1),
#  ('96.254.233.150', 6),
#  ('217.69.133.235', 1),
#  ('60.29.35.14', 2),
#  ('158.136.112.187', 1),
#  ('195.38.23.137', 2),
#  ('180.211.69.209', 1),
#  ('193.167.195.60', 6),
#  ('223.67.143.84', 1),
#  ('198.55.109.202', 2),
#  ('5.235.199.240', 1),
#  ('2.85.194.19', 1),
#  ('212.107.116.234', 1),
#  ('182.253.23.3', 6),
#  ('62.210.189.45', 1),
#  ('199.187.125.26', 1),
#  ('173.200.233.195', 1),
#  ('106.78.19.160', 18),
#  ('31.150.236.68', 1),
#  ('178.213.67.2', 1),
#  ('200.141.109.74', 1),
#  ('114.250.134.175', 1),
#  ('82.209.214.162', 1),
#  ('184.154.149.126', 2),
#  ('173.236.32.219', 1),
#  ('84.233.151.236', 6),
#  ('200.68.86.233', 6),
#  ('173.166.158.222', 6),
#  ('180.169.2.99', 1),
#  ('98.245.87.136', 2),
#  ('213.174.192.220', 6),
#  ('108.178.45.172', 1),
#  ('82.178.75.63', 1),
#  ('72.182.73.81', 1),
#  ('54.236.213.208', 1),
#  ('208.88.254.164', 1),
#  ('75.127.15.68', 1),
#  ('96.127.149.186', 1),
#  ('198.167.137.193', 2),
#  ('62.12.14.27', 6),
#  ('188.165.243.45', 3),
#  ('176.46.113.39', 1),
#  ('186.202.153.56', 1),
#  ('177.132.188.205', 6),
#  ('82.135.32.98', 7),
#  ('54.215.96.68', 1),
#  ('194.171.252.104', 6),
#  ('83.206.120.18', 6),
#  ('129.184.84.11', 4),
#  ('129.184.84.12', 1),
#  ('50.2.225.202', 1),
#  ('80.187.96.71', 4),
#  ('125.122.211.40', 6),
#  ('108.15.20.23', 6),
#  ('108.61.140.67', 1),
#  ('194.105.145.147', 6),
#  ('54.242.115.144', 1),
#  ('66.249.85.135', 2),
#  ('178.17.6.226', 6),
#  ('24.5.221.92', 5),
#  ('147.210.12.12', 1),
#  ('198.208.159.20', 1),
#  ('170.148.69.141', 8),
#  ('99.6.61.4', 6),
#  ('198.50.227.136', 2),
#  ('173.213.97.176', 2),
#  ('200.85.183.174', 6),
#  ('14.18.25.243', 6),
#  ('157.55.33.19', 3),
#  ('83.69.235.12', 6),
#  ('96.63.29.108', 6),
#  ('195.37.190.67', 1),
#  ('92.96.157.230', 1),
#  ('37.11.0.8', 13),
#  ('131.107.160.94', 1),
#  ('37.252.127.97', 1),
#  ('213.181.52.10', 6),
#  ('194.153.130.2', 1),
#  ('92.237.208.151', 2),
#  ('97.74.24.113', 1),
#  ('50.157.244.41', 4),
#  ('70.177.214.34', 1),
#  ('188.9.138.189', 8),
#  ('79.215.79.185', 1),
#  ('180.76.5.69', 1),
#  ('70.197.6.64', 1),
#  ('159.50.249.148', 2),
#  ('159.50.249.150', 4),
#  ('203.145.79.41', 2),
#  ('183.221.90.177', 6),
#  ('211.125.92.233', 1),
#  ('87.109.78.50', 1),
#  ('83.25.215.235', 1),
#  ('109.9.166.16', 1),
#  ('185.38.249.133', 2),
#  ('130.193.173.90', 1),
#  ('91.236.74.121', 1),
#  ('129.27.3.93', 2),
#  ('128.147.28.1', 7),
#  ('72.54.172.193', 6),
#  ('216.143.11.118', 7),
#  ('81.210.53.2', 6),
#  ('109.190.148.218', 6),
#  ('177.37.5.6', 2),
#  ('173.236.34.182', 1),
#  ('199.30.20.64', 2),
#  ('213.150.233.62', 6),
#  ('79.148.255.215', 2),
#  ('109.231.204.82', 6),
#  ('80.130.134.87', 2),
#  ('24.0.194.37', 32),
#  ('180.76.5.189', 1),
#  ('132.252.139.85', 10),
#  ('72.177.92.9', 1),
#  ('8.35.201.53', 2),
#  ('216.16.195.52', 2),
#  ('95.108.158.230', 2),
#  ('68.14.231.140', 3),
#  ('67.225.29.201', 1),
#  ('199.59.148.211', 2),
#  ('81.190.174.219', 19),
#  ('99.100.25.83', 1),
#  ('183.60.214.19', 1),
#  ('115.245.219.74', 1),
#  ('132.229.223.2', 7),
#  ('189.11.65.66', 6),
#  ('80.108.184.97', 3),
#  ('77.234.68.135', 2),
#  ('212.101.243.11', 1),
#  ('177.6.142.6', 6),
#  ('165.145.12.44', 2),
#  ('91.191.197.87', 1),
#  ('185.37.161.34', 1),
#  ('174.26.93.238', 6),
#  ('8.35.201.54', 1),
#  ('8.35.201.49', 2),
#  ('5.144.176.110', 2),
#  ('190.1.111.247', 1),
#  ('5.10.83.23', 5),
#  ('93.80.29.12', 6),
#  ('199.204.56.18', 6),
#  ('180.76.5.187', 1),
#  ('180.76.5.28', 1),
#  ('204.93.54.167', 2),
#  ('82.24.16.46', 1),
#  ('62.159.77.167', 6),
#  ('197.237.89.221', 1),
#  ('165.139.161.160', 1),
#  ('150.162.56.185', 23),
#  ('195.176.191.93', 6),
#  ('180.76.6.141', 1),
#  ('108.184.124.170', 2),
#  ('177.141.70.11', 6),
#  ('195.176.110.194', 1),
#  ('5.10.83.91', 5),
#  ('49.206.120.190', 5),
#  ('82.60.18.23', 2),
#  ('24.190.3.5', 1),
#  ('74.76.53.142', 6),
#  ('68.87.42.115', 1),
#  ('54.204.20.250', 1),
#  ('173.232.106.129', 2),
#  ('5.135.113.131', 2),
#  ('65.55.52.111', 1),
#  ('188.238.146.131', 1),
#  ('78.57.150.9', 2),
#  ('62.4.19.142', 2),
#  ('180.76.5.114', 1),
#  ('5.10.83.21', 4),
#  ('204.62.56.3', 34),
#  ('155.201.35.55', 6),
#  ('157.56.92.142', 1),
#  ('204.236.190.162', 1),
#  ('24.97.227.132', 5),
#  ('50.131.220.143', 7),
#  ('24.130.53.65', 6),
#  ('98.173.30.75', 2),
#  ('2.38.110.208', 1),
#  ('41.249.219.90', 1),
#  ('194.237.142.21', 1),
#  ('68.189.165.19', 1),
#  ('157.55.33.183', 1),
#  ('184.154.170.122', 2),
#  ('182.253.73.95', 2),
#  ('92.100.97.83', 2),
#  ('23.229.67.14', 4),
#  ('99.146.78.102', 1),
#  ('190.107.140.178', 1),
#  ('180.76.5.73', 1),
#  ('208.43.251.180', 9),
#  ('99.17.221.6', 2),
#  ('173.252.110.115', 1),
#  ('173.252.103.7', 1),
#  ('91.180.146.16', 6),
#  ('78.19.193.147', 6),
#  ('24.114.40.26', 1),
#  ('86.166.162.41', 2),
#  ('5.10.83.53', 4),
#  ('189.71.37.115', 6),
#  ('12.110.81.190', 7),
#  ('195.194.187.106', 7),
#  ('148.241.190.81', 1),
#  ('184.169.185.164', 1),
#  ('157.55.33.17', 1),
#  ('82.130.49.223', 6),
#  ('31.4.197.143', 6),
#  ('184.148.132.111', 1),
#  ('199.30.24.78', 1),
#  ('54.203.120.42', 1),
#  ('173.164.44.34', 6),
#  ('192.99.12.169', 2),
#  ('70.42.255.243', 1),
#  ('212.180.233.101', 6),
#  ('109.163.234.2', 1),
#  ('108.28.155.98', 6),
#  ('116.199.211.249', 1),
#  ('46.119.114.245', 1),
#  ('63.140.98.80', 8),
#  ('180.76.6.56', 1),
#  ('24.236.252.67', 1),
#  ('93.114.45.13', 6),
#  ('66.249.73.135', 482),
#  ('50.16.19.13', 113),
#  ('66.249.73.185', 56),
#  ('50.150.204.184', 1),
#  ('207.241.237.225', 13),
#  ('200.49.190.101', 3),
#  ('91.177.205.119', 6),
#  ('207.241.237.101', 17),
#  ('87.169.99.232', 1),
#  ('209.85.238.199', 102),
#  ('81.220.24.207', 6),
#  ('74.125.40.20', 2),
#  ('108.174.55.234', 23),
#  ('121.107.188.202', 1),
#  ('198.46.149.143', 82),
#  ('50.180.79.170', 2),
#  ('105.235.130.196', 6),
#  ('54.255.13.204', 6),
#  ('68.184.202.186', 6),
#  ('24.233.162.179', 1),
#  ('220.181.108.153', 1),
#  ('97.116.185.190', 6),
#  ('5.255.72.168', 2),
#  ('208.91.156.11', 60),
#  ('74.125.176.81', 1),
#  ('90.220.199.149', 6),
#  ('212.201.44.247', 2),
#  ('82.193.99.33', 3),
#  ('85.170.84.143', 5),
#  ('100.43.83.137', 84),
#  ('112.110.247.238', 1),
#  ('203.118.242.184', 1),
#  ('212.242.185.85', 6),
#  ('68.180.224.225', 99),
#  ('223.81.196.65', 1),
#  ('178.191.44.227', 2),
#  ('94.228.34.233', 7),
#  ('88.112.19.251', 11),
#  ('79.185.184.23', 6),
#  ('207.241.237.102', 13),
#  ('66.168.50.129', 1),
#  ('82.247.137.135', 6),
#  ('74.125.40.16', 2),
#  ('86.182.52.145', 6),
#  ('92.239.20.53', 2),
#  ('173.192.238.41', 3),
#  ('207.241.237.223', 21),
#  ('199.16.156.126', 8),
#  ('193.238.231.119', 6),
#  ('199.16.156.125', 9),
#  ('207.241.237.226', 11),
#  ('54.220.160.83', 5),
#  ('74.125.40.22', 3),
#  ('66.249.81.20', 4),
#  ('144.76.194.187', 41),
#  ('75.97.9.59', 273),
#  ('50.195.216.83', 1),
#  ('202.156.10.254', 3),
#  ('65.55.213.79', 7),
#  ('117.227.171.181', 6),
#  ('65.55.213.74', 29),
#  ('81.169.149.220', 1),
#  ('217.212.224.183', 2),
#  ('217.212.224.181', 5),
#  ('192.95.12.193', 4),
#  ('41.223.160.234', 1),
#  ('198.228.201.147', 3),
#  ('89.2.87.1', 18),
#  ('89.176.234.221', 1),
#  ('208.54.40.237', 6),
#  ('166.147.88.15', 5),
#  ('183.60.243.242', 1),
#  ('82.165.139.53', 5),
#  ('23.231.5.40', 1),
#  ('180.76.6.48', 1),
#  ('31.142.223.246', 1),
#  ('80.153.191.173', 6),
#  ('119.63.196.16', 1),
#  ('180.180.119.57', 2),
#  ('89.170.74.95', 2),
#  ('157.55.32.190', 4),
#  ('80.237.234.150', 4),
#  ('94.222.112.110', 6),
#  ('74.125.176.146', 9),
#  ('195.248.32.227', 5),
#  ('116.125.143.84', 2),
#  ('54.219.224.86', 1),
#  ('99.188.185.40', 1),
#  ('202.65.130.3', 1),
#  ('201.244.101.132', 1),
#  ('109.87.146.211', 1),
#  ('89.100.113.231', 1),
#  ('185.26.239.20', 2),
#  ('213.21.42.46', 6),
#  ('84.198.71.68', 1),
#  ('74.208.180.23', 1),
#  ('71.171.122.192', 1),
#  ('66.249.81.91', 13),
#  ('74.125.40.17', 3),
#  ('75.134.169.174', 6),
#  ('157.56.92.158', 3),
#  ('194.94.204.181', 2),
#  ('70.190.77.28', 2),
#  ('192.30.34.115', 1),
#  ('50.132.55.62', 5),
#  ('112.110.247.233', 1),
#  ('112.110.247.227', 1),
#  ('208.93.0.48', 19),
#  ('107.170.40.199', 6),
#  ('42.107.175.146', 5),
#  ('74.218.234.48', 6),
#  ('98.85.3.179', 2),
#  ('46.118.118.101', 1),
#  ...]

# %%
ipCounts.take(20)
# Out:
# [('83.149.9.216', 23),
#  ('110.136.166.128', 6),
#  ('46.105.14.53', 364),
#  ('123.125.71.35', 1),
#  ('200.49.190.100', 1),
#  ('67.214.178.190', 2),
#  ('207.241.237.220', 18),
#  ('207.241.237.227', 17),
#  ('207.241.237.228', 16),
#  ('218.30.103.62', 16),
#  ('71.212.224.97', 5),
#  ('86.1.76.62', 6),
#  ('107.170.41.69', 10),
#  ('208.115.111.72', 83),
#  ('174.37.205.76', 1),
#  ('134.76.249.10', 8),
#  ('123.125.71.117', 1),
#  ('65.19.138.34', 3),
#  ('5.102.173.71', 2),
#  ('187.45.193.158', 8)]

# %% [markdown]
# Sort by values (ascending):

# %%
ipCounts.takeOrdered(10, lambda pair: pair[1])
# Out:
# [('123.125.71.35', 1),
#  ('200.49.190.100', 1),
#  ('174.37.205.76', 1),
#  ('123.125.71.117', 1),
#  ('180.76.5.27', 1),
#  ('93.164.60.142', 1),
#  ('94.175.135.116', 1),
#  ('172.56.29.98', 1),
#  ('173.252.73.114', 1),
#  ('54.226.176.99', 1)]

# %% [markdown]
# Sort by values (descending):

# %%
topIPs = ipCounts.takeOrdered(10, lambda pair: -pair[1])
topIPs
# Out:
# [('66.249.73.135', 482),
#  ('46.105.14.53', 364),
#  ('130.237.218.86', 357),
#  ('75.97.9.59', 273),
#  ('50.16.19.13', 113),
#  ('209.85.238.199', 102),
#  ('68.180.224.225', 99),
#  ('100.43.83.137', 84),
#  ('208.115.111.72', 83),
#  ('198.46.149.143', 82)]

# %% [markdown]
# ### Plotting

# %%
import pandas as pd

# %%
df = pd.DataFrame(topIPs, columns=['IP', 'Count'])
df
# Out:
#                IP  Count
# 0   66.249.73.135    482
# 1    46.105.14.53    364
# 2  130.237.218.86    357
# 3      75.97.9.59    273
# 4     50.16.19.13    113
# 5  209.85.238.199    102
# 6  68.180.224.225     99
# 7   100.43.83.137     84
# 8  208.115.111.72     83
# 9  198.46.149.143     82

# %%
import matplotlib.pyplot as plt

# %%
df.plot.barh(x = 'IP')
# Out:
# <Axes: ylabel='IP'>

# %% [markdown]
# ### Closures and accumulators

# %% [markdown]
# Local variables are not passed to closures or functions, they remain local!

# %%
counter = 0

# Wrong: Don't do this!!
def increment_counter(x):
    global counter
    counter += x

wordCounts.foreach(increment_counter)

print("Counter value: ", counter)
# Out:
# Counter value:  0

# %% [markdown]
# Use *accumulators* instead

# %%
accum = sc.accumulator(0)
accum
# Out:
# Accumulator<id=0, value=0>

# %%
# Correct way is to use accumulators
def increment_counter(x):
    accum.add(x)

wordCounts.foreach(increment_counter)

print("Counter value: ", accum)
# Out:
# Counter value:  197956
